# %%
import imutils
from imutils import paths
import cv2
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
from sklearn.decomposition import PCA

# %%
dataset = []
def extract_images_from_folder(folder_path, target_size):
    
    for filename in os.listdir(folder_path):
        img_path = os.path.join(folder_path, filename)
        img = cv2.imread(img_path)

        if img is not None:
            img = cv2.resize(img, target_size)  # Resize the image to a consistent shape
            dataset.append(img)
        else:
            print(f"Could not read the image at {img_path}")

# Example usage:
folder_path = 'C:/Users/Rishi/Desktop/New folder/Dataset/Lhasa'  # Replace with the path to your image folder
target_size = (800, 400)  # Set your target size for resizing
image_array = extract_images_from_folder(folder_path, target_size)

# %%
lhasa19= dataset[0]

# %%
plt.imshow(lhasa19)

# %%
lhasa22= dataset[1]

# %%
plt.imshow(lhasa22)

# %%
lhasa22.shape
# Out:
# (400, 800, 3)

# %%
lhasa22= lhasa22[:,:,0]

# %%
lhasa19= lhasa19[:,:,0]

# %%
pca= PCA(0.95)

# %%
dataset=np.array(dataset)

# %%
dataset.shape
# Out:
# (2, 400, 800, 3)

# %%
dataset= dataset[:,:,:,0]

# %%
dataset.shape
# Out:
# (2, 400, 800)

# %%
dataset= dataset.reshape((2,400*800))

# %%
dataset.shape
# Out:
# (2, 320000)

# %%
pca= PCA(0.95)

# %%
pca.fit(dataset)
# Out:
# PCA(n_components=0.95)

# %%
pca.components_.size
# Out:
# 320000

# %%
plt.imshow(pca.components_[0].reshape(400,800),cmap=plt.cm.bone)

# %%
dataset1 = []
def extract_images_from_folder(folder_path, target_size):
    
    for filename in os.listdir(folder_path):
        img_path = os.path.join(folder_path, filename)
        img = cv2.imread(img_path)

        if img is not None:
            img = cv2.resize(img, target_size)  # Resize the image to a consistent shape
            dataset1.append(img)
        else:
            print(f"Could not read the image at {img_path}")

# Example usage:
folder_path = 'C:/Users/Rishi/Desktop/New folder/Dataset/Hotan'  # Replace with the path to your image folder
target_size = (800, 400)  # Set your target size for resizing
image_array = extract_images_from_folder(folder_path, target_size)

# %%
plt.imshow(dataset1[0])

# %%
plt.imshow(dataset1[1])

# %%
dataset1=np.array(dataset1)

# %%
dataset1.shape
# Out:
# (2, 400, 800, 3)

# %%
dataset1= dataset1[:,:,:,0]

# %%
dataset1.shape
# Out:
# (2, 400, 800)

# %%
dataset1= dataset1.reshape((2,400*800))

# %%
pca= PCA(0.95)

# %%
pca.fit(dataset1)
# Out:
# PCA(n_components=0.95)

# %%
plt.imshow(pca.components_[0].reshape(400,800),cmap=plt.cm.bone)

# %%
hindon = []
def extract_images_from_folder(folder_path, target_size):
    
    for filename in os.listdir(folder_path):
        img_path = os.path.join(folder_path, filename)
        img = cv2.imread(img_path)

        if img is not None:
            img = cv2.resize(img, target_size)  # Resize the image to a consistent shape
            hindon.append(img)
        else:
            print(f"Could not read the image at {img_path}")

# Example usage:
folder_path = 'C:/Users/Rishi/Desktop/New folder/Dataset/Hindon'  # Replace with the path to your image folder
target_size = (800, 400)  # Set your target size for resizing
image_array = extract_images_from_folder(folder_path, target_size)

# %%
plt.imshow(hindon[0])

# %%
plt.imshow(hindon[1])

# %%
hindon= np.array(hindon)

# %%
hindon.shape
# Out:
# (2, 400, 800, 3)

# %%
hindon= hindon[:,:,:,0]

# %%
hindon.shape
# Out:
# (2, 400, 800)

# %%
hindon= hindon.reshape((2,400*800))

# %%
pca= PCA(0.95)

# %%
pca.fit(hindon)
# Out:
# PCA(n_components=0.95)

# %%
plt.imshow(pca.components_[0].reshape(400,800),cmap=plt.cm.bone)

# %%
ambala = []
def extract_images_from_folder(folder_path, target_size):
    
    for filename in os.listdir(folder_path):
        img_path = os.path.join(folder_path, filename)
        img = cv2.imread(img_path)

        if img is not None:
            img = cv2.resize(img, target_size)  # Resize the image to a consistent shape
            ambala.append(img)
        else:
            print(f"Could not read the image at {img_path}")

# Example usage:
folder_path = 'C:/Users/Rishi/Desktop/New folder/Dataset/Ambala'  # Replace with the path to your image folder
target_size = (800, 400)  # Set your target size for resizing
image_array = extract_images_from_folder(folder_path, target_size)

# %%
plt.imshow(ambala[0])

# %%
plt.imshow(ambala[1])

# %%
ambala= np.array(ambala)

# %%
ambala.shape
# Out:
# (2, 400, 800, 3)

# %%
ambala= ambala[:,:,:,0]

# %%
ambala= ambala.reshape((2,400*800))

# %%
pca= PCA(0.95)

# %%
pca.fit(ambala)
# Out:
# PCA(n_components=0.95)

# %%
plt.imshow(pca.components_[0].reshape(400,800),cmap=plt.cm.bone)

# %%
print("Therefore we can see that Indian Airforces do not have good improvements but China has done alot of improvements in the airsbases")
# Out:
# Therefore we can see that Indian Airforces do not have good improvements but China has done alot of improvements in the airsbases
